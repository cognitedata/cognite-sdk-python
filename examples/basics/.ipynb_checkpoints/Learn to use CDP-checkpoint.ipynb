# %% [markdown]
# # Prerequisites
#
# - Install the [Cognite Python SDK](https://github.com/cognitedata/cognite-sdk-python)
# - Make sure that you have received an API key from http://openindustrialdata.com/
# - Set the API key as an environment variable, see instructions in the Cognite Python SDK [github repository](https://github.com/cognitedata/cognite-sdk-python)

# %% [markdown]
# # Get started
#
# First, we make the imports we'll need for this mini-intro

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as plt

from datetime import datetime

from cognite.config import configure_session

from cognite.v05.assets import get_assets
from cognite.v05.assets import get_asset
from cognite.v05.assets import get_asset_subtree

from cognite.v05.files import list_files
from cognite.v05.files import get_file_info
from cognite.v05.files import download_file

from cognite.v05.timeseries import get_datapoints_frame
from cognite.v05.timeseries import get_timeseries

from cognite.v05.tagmatching import tag_matching

# %% [markdown]
# # The API key is needed to authenticate
# Use your API key to authenticate. Make sure that you have first set the API key as an environment variable.
#
# Your API key is specific to a project. Now we will work with the data as part of the Open Industrial Data. The project is then called "public data"

# %%
configure_session(os.environ['PUBLICDATA_API_KEY'], 'publicdata')

# %% [markdown]
# # Data in the Cognite Data Platform is structured around assets
#
# The data in the Cognite Data Platform is structured by assets, where an asset can be a specific piece of equipment or an equipment type.
#
# We'll get all assets with get_assets(). You can also include a description or asset name as a parameter -- see more information in the reference docs.

# %%
assets = get_assets()
assets

# %% [markdown]
# The API returns response objects. We have added a .to_pandas() method in the Python SDK which makes it easier to view the data.

# %%
assets_df = assets.to_pandas()
assets_df
# Out:
#                                             description                id  \
# 0                 GAS COMPRESSION AND RE-INJECTION (PH)  3111454725058294
# 1                 1ST STAGE COMP DRY GAS SEAL SYS ON PH  3904753668320840
# 2                        1ST STAGE COMP ENCLOSURE ON PH  2499711953216311
# 3                     1ST STAGE COMP LUBE OIL SYS ON PH  2137557577165478
# 4                           1ST STAGE COMPRESSION ON PH  4518112062673878
# 5                            1ST STAGE COMPRESSOR ON PH  7372310232665628
# 6                 2ND STAGE COMP DRY GAS SEAL SYS ON PH  6658342189327214
# 7                           2ND STAGE COMPRESSION ON PH  5786472304680477
# 8                            2ND STAGE COMPRESSOR ON PH  4074033093163622
# 9                       VRD - PH 1STSTGSUCT SCRUB INLET  1145062594143414
# 10                    VRD - PH 1STSTGSUCT SCRUB GAS OUT  4429460770230545
# 11                    VRD - PH 1STSTGSUCT SCRUB LIQ OUT  6411851961004971
# 12         VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER A  8790823573167638
# 13         VRD - 1ST STAGE COMPRESSOR LUBE OIL FILTER B   379497117972793
# 14         VRD - 1ST STAGE COMPRESSOR GAS SEAL FILTER A  1510541513998137
# 15         VRD - 1ST STAGE COMPRESSOR GAS SEAL FILTER B  8230264121219051
# 16         VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER A  5062762658885662
# 17         VRD - 1ST STAGE COMPRESSOR NITROGEN FILTER B   928299407571359
# 18    VRD - 1ST STAGE COMPRESSOR SEAL GAS BOOSTER FI...  6294957040877606
# 19    VRD - DRIVE-AIR FILTER SEAL GAS  STAGE 1 COMPR...  1843088354536778
# 20                VRD - 1ST STAGE COMPRESSOR PURGE UNIT  6800693372982143
# 21                 VRD - 1ST STAGE COMPRESSOR GEAR UNIT  3117826349444493
# 22    VRD - 1ST STAGE COMPPRESSOR ENCLOSURE COALESCE...  6849981120182174
# 23                        VRD - PH 1STSTGSUCTCLR GAS IN  8921694964498486
# 24                  VRD - PH 1STSTGSUCTCLR GAS IN EQUAL  7253555045795726
# 25                  VRD - PH 1ST STG SUCT SCRUB LIQ OUT  2275546579263109
# 26                    VRD - PH 1ST STG SUCT CLR GAS OUT  4221533120627422
# 27              VRD - PH 1ST STG SUCT CLR GAS OUT EQUAL  4495106577345324
# 28                        VRD - PH 1STSTGSUCTCLR GAS IN  2224441670194138
# 29                  VRD - PH 1STSTGSUCTCLR GAS IN EQUAL  1589550778681952
# ...                                                 ...               ...
# 1076               VRD - PH COMPENCSTG1 WTRMIST REL DR2  8405693688641054
# 1077   VRD - STAGE 1 COMPRESSOR WATER MIST DELUGE VALVE  7934204124030408
# 1078                 VRD - PH STG1 COMP WTR MIST N2 RLS  6668269779432816
# 1079                VRD - PH STG1 COMP WTR MIST WTR RLS  1273695705658584
# 1080               VRD - PH STG1 COMP WTR MIST N2 CYL 1  7700614960472097
# 1081               VRD - PH STG1 COMP WTR MIST N2 CYL 2  8903769887622255
# 1082                VRD - PH STG1 COMP WTR MIST RELEASE  3279134232632771
# 1083                VRD - PH STG1 COMP WTR MIST AIR RLS  8889755680547713
# 1084               VRD - PH STG1 COMPENCL AIROUT DAMPER  1707240882791549
# 1085               VRD - PH STG1 COMPENCL AIR IN DAMPER  6778902765489857
# 1086               VRD - PH STG1 COMPENCL AIROUT DAMPER  6952379760259213
# 1087               VRD - PH STG1 COMPENCL AIR IN DAMPER  2780685839869079
# 1088               VRD - PH STG1 COMPENCL AIROUT DAMPER  1557796748623584
# 1089               VRD - PH STG1 COMPENCL AIR IN DAMPER   453584366849025
# 1090           VRD - MOTOR STARTER 1ST STAGE COMPRESSOR  7886783194876402
# 1091         VRD - 1ST STAGE COMPRESSOR LUBE OIL HEATER  7200619527605764
# 1092  VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING U...  6345357386172745
# 1093         VRD - 1ST STAGE COMPRESSOR BACKUP LO. PUMP  2179240149049404
# 1094     VRD - 1ST STAGE COMPRESSOR OIL SEPERATOR W/FAN  7254018244705798
# 1095  VRD - 1ST STAGE COMPRESSOR ENCLOSURE COOLING U...  3810759783087892
# 1096  FEEDER THYRISTOR +82B SEAL GAS HEATER FOR 1 ST...   135258102320048
# 1097      THYRISTOR SEAL GAS HEATER FOR 1 ST STAGE COMP  8084121028357216
# 1098  VRD - MONORAIL OVER WALKWAY FOR EQUIPMENT ON S...  4147550425178087
# 1099                                            Aker BP  6687602007296940
# 1100               VRD - CONE STRAINER, 250%, 1/8"HOLES  5326102006389244
# 1101                VRD - FLAME ARRESTOR (IN LINE TYPE)   595827253516334
# 1102                  VRD - 32"X 30" FLANGED TRANSITION  6412414807505833
# 1103  VRD - NOISE CONTROL SPOOL (1ST STAGE COMPRESS....  8693879864360723
# 1104  VRD - EXPANSION JOINT (1ST STAGE COMPRESSOR LU...  5361696249222358
# 1105                                  Valhall plattform  4650652196144007
#
#                                                metadata  \
# 0     {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...
# 1     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 2     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 3     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 4     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 5     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 6     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 7     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 8     {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 9     {'ELC_STATUS_ID': '1211', 'RES_ID': '531669', ...
# 10    {'ELC_STATUS_ID': '1211', 'RES_ID': '531669', ...
# 11    {'ELC_STATUS_ID': '1211', 'RES_ID': '531668', ...
# 12    {'ELC_STATUS_ID': '1211', 'RES_ID': '746776', ...
# 13    {'ELC_STATUS_ID': '1211', 'RES_ID': '746776', ...
# 14    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 15    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 16    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 17    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 18    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 19    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 20    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 21    {'ELC_STATUS_ID': '1211', 'RES_ID': '490395', ...
# 22    {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 23    {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 24    {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 25    {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 26    {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 27    {'ELC_STATUS_ID': '1211', 'RES_ID': '532127', ...
# 28    {'ELC_STATUS_ID': '1211', 'RES_ID': '530799', ...
# 29    {'ELC_STATUS_ID': '1211', 'RES_ID': '530799', ...
# ...                                                 ...
# 1076  {'ELC_STATUS_ID': '1211', 'RES_ID': '550353', ...
# 1077  {'ELC_STATUS_ID': '1225', 'SOURCE_DB': 'workma...
# 1078  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1079  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1080  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1081  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1082  {'ELC_STATUS_ID': '1211', 'RES_ID': '303954', ...
# 1083  {'ELC_STATUS_ID': '1211', 'RES_ID': '222320', ...
# 1084  {'ELC_STATUS_ID': '1211', 'RES_ID': '222320', ...
# 1085  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1086  {'ELC_STATUS_ID': '1211', 'RES_ID': '448303', ...
# 1087  {'ELC_STATUS_ID': '1211', 'RES_ID': '448303', ...
# 1088  {'ELC_STATUS_ID': '1211', 'RES_ID': '448303', ...
# 1089  {'ELC_STATUS_ID': '1211', 'RES_ID': '448303', ...
# 1090  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1091  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1092  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1093  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1094  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1095  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1096  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1097  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1098  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1099                                                NaN
# 1100  {'ELC_STATUS_ID': '1211', 'RES_ID': '531018', ...
# 1101  {'ELC_STATUS_ID': '1211', 'RES_ID': '653589', ...
# 1102  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1103  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1104  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 1105  {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...
#
#                                        name      parentId  \
# 0                                        23  4.650652e+15
# 1     23-1ST STAGE COMP DRY GAS SEAL SYS-PH  4.856008e+15
# 2            23-1ST STAGE COMP ENCLOSURE-PH  4.856008e+15
# 3         23-1ST STAGE COMP LUBE OIL SYS-PH  4.856008e+15
# 4               23-1ST STAGE COMPRESSION-PH  6.895992e+15
# 5                23-1ST STAGE COMPRESSOR-PH  4.518112e+15
# 6     23-2ND STAGE COMP DRY GAS SEAL SYS-PH  4.222791e+15
# 7               23-2ND STAGE COMPRESSION-PH  6.895992e+15
# 8                23-2ND STAGE COMPRESSOR-PH  5.786472e+15
# 9                            23-AE-92527-S1  5.323189e+13
# 10                           23-AE-92527-S2  5.323189e+13
# - PH-ME-P-0152-001: 1 st stage suction scrubber
# - PH-ME-P-0153-001: 1 st stage compressor
# - PH-ME-P-0156-001: 1 st stage compressor. Temperatur and vibration monitoring
# - PH-ME-P-0156-002: 1 st stage compressor. Temperatur and vibration monitoring
# - PH-ME-0160-001: 1 st stage discharge cooler
#
# We can have a look at the PID for the 1st stage suction scrubber.

# %%
scrubber_file_name = 'PH-ME-P-0152-001'
list_files(name=scrubber_file_name).to_pandas()
# Out:
#      createdTime                                          directory  \
# 0  1533213439872  /BP Operated Licenses/PL006B Valhall/99 Docume...
#
#            fileName fileType                id  lastUpdatedTime  \
# 0  PH-ME-P-0152-001     tiff  6292237976899896    1533213483919
#
#                                             metadata      source  uploaded  \
# 0  {'area_name': 'PH,INTERMEDIATE DECK COOLER & S...  Documentum      True
#
#       uploadedAt
# 0  1533213483919

# %%
# Now download the file using the file id
download_file(6292237976899896)
# Out:
# 'https://storage.googleapis.com/cognite-storage/5977964818434649/6292237976899896/PH-ME-P-0152-001?GoogleAccessId=cloud-storage@cognitedata.iam.gserviceaccount.com&Expires=1533894418&Signature=cDVTeLKAZ8fMLwnID%2F%2F6xj8i0%2FT8KobX%2BsKNJ5R2BDRMSeYEy1Hg1ftd5LUdkw%2BuDA8WRM3uKHIDVUdOcVN3obX7KaPg4lw5WACtqQ5o%2BMvtKaYLqQoFrK6h7v5kGp57DJxYtlGwSInLk9QURUTfq2%2BZAb7Q6wvmZMt8qPGlrLdw2peIS8wp51ASEEnbEFm0lyutp3eig8o52kpvLLvG%2BvOFba6CkfIHumaIiWRw4rGK6mtBGeri5c%2BnPIuKGKc4mJtnRUwp2vPy6iGQMg6UflwKU1kT7f%2FKwsBcCSKj2CkhRe%2FCqKdxucpwFYYhjevAjvXrNvPMspEG2H3SojJOog%3D%3D'

# %% [markdown]
# If you run the code yourself, you will get a new download url which you can use to look at the P&ID in the browser.
#
# Skilled engineers can look at the P&ID and understand how the system works. I asked an engineer and was told that I could look at timeseries for the following:
#
# - The scrubber level working setpoint (tag name = 'VAL_23-LIC-92521:Control Module:YR')
# - The scrubber level measured value (tag name = 'VAL_23-LIC-92521:Z.X.Value')
# - The scrubber level output (tag name = 'VAL_23-LIC-92521:Z.Y.Value')

# %% [markdown]
# ### Specify the data

# %% [markdown]
# We can get the relevant data for the scrubber level setpoint, measured value, and output.

# %%
scrubber_level_working_setpoint = 'VAL_23-LIC-92521:Control Module:YR'
scrubber_level_measured_value  = 'VAL_23-LIC-92521:Z.X.Value'
scrubber_level_output  = 'VAL_23-LIC-92521:Z.Y.Value'
all_ts_names = [scrubber_level_working_setpoint, scrubber_level_measured_value, scrubber_level_output]
print(all_ts_names)
# Out:
# ['VAL_23-LIC-92521:Control Module:YR', 'VAL_23-LIC-92521:Z.X.Value', 'VAL_23-LIC-92521:Z.Y.Value']

# %% [markdown]
# One way to pull data is using the function get_datapoints_frame. See reference documentation, http://cognite-sdk-python.readthedocs.io/en/latest/cognite.html#module-cognite.v05.timeseries.
#
# This function gets datapoints for given timeseries all on the same timestamps, saving you from otherwise interpolating to get the timeseries data on the same timestamps.
#
# Specifying a start and end time gives you data for the desired time range
# Granularity of 1 hour pulls a single aggregate value for all data points per hour
# Providing multiple aggregates pulls data using all the three aggregates

# %%
start = datetime(2018, 7, 1)
end = '1d-ago'
data = get_datapoints_frame(all_ts_names, start=start, end=end, granularity='1h', aggregates=['average', 'min', 'max'])

# %% [markdown]
# ### Investigate the data
# The data is returned with the timeseries for the different aggregates in the columns.

# %%
data.head()
# Out:
#        timestamp  VAL_23-LIC-92521:Control Module:YR|average  \
# 0  1530403200000                                        35.0
# 1  1530406800000                                        35.0
# 2  1530410400000                                        35.0
# 3  1530414000000                                        35.0
# 4  1530417600000                                        35.0
#
#    VAL_23-LIC-92521:Control Module:YR|min  \
# 0                                    35.0
# 1                                    35.0
# 2                                    35.0
# 3                                    35.0
# 4                                    35.0
#
#    VAL_23-LIC-92521:Control Module:YR|max  VAL_23-LIC-92521:Z.X.Value|average  \
# 0                                    35.0                           35.127482
# 1                                    35.0                           34.926104
# 2                                    35.0                           34.663202
# 3                                    35.0                           35.144910
# 4                                    35.0                           35.099385
#
#    VAL_23-LIC-92521:Z.X.Value|min  VAL_23-LIC-92521:Z.X.Value|max  \
# 0                       34.287022                       36.580452
# 1                       33.992523                       36.231022
# 2                       33.580528                       36.017395
# 3                       34.268711                       36.311893
# 4                       34.280918                       36.099792
#
#    VAL_23-LIC-92521:Z.Y.Value|average  VAL_23-LIC-92521:Z.Y.Value|min  \
# 0                           36.225898                       32.852486
# 1                           35.466413                       31.533926
# 2                           31.829551                       26.072357
# 3                           33.104658                       29.197401
# 4                           33.911751                       30.431208
#
#    VAL_23-LIC-92521:Z.Y.Value|max
# 0                       41.348152
# 1                       39.901684
# 2                       38.202591
# 3                       37.303951
# 4                       38.298256

# %% [markdown]
# Substitute missing values before plotting the data. Pandas has useful functionality for this, e.g. see https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.DataFrame.fillna.html.

# %%
data = data.fillna(method='ffill')

# %% [markdown]
# ### Visualize the data

# %%
T = pd.to_datetime(data.timestamp, unit='ms')
plt.figure(figsize=(10, 5))
plt.plot(T, data[scrubber_level_working_setpoint+'|average'].values, label='setpoint')
plt.plot(T, data[scrubber_level_measured_value+'|average'].values, label='measured value')
plt.plot(T, data[scrubber_level_output+'|average'].values, label='level output')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e8872a8252d0> in <module>()
#       1 T = pd.to_datetime(data.timestamp, unit='ms')
# ----> 2 plt.figure(figsize=(10, 5))
#       3 plt.plot(T, data[scrubber_level_working_setpoint+'|average'].values, label='setpoint')
#       4 plt.plot(T, data[scrubber_level_measured_value+'|average'].values, label='measured value')
#       5 plt.plot(T, data[scrubber_level_output+'|average'].values, label='level output')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Wooh, you've made a plot! Now what does this data mean?
#
# Background:
# - The blue line is the desired level in the scrubber.
# - The orange line is actual, measured value in the scrubber.
# - The green line is the output from the scrubber to control the level in the scrubber.
#
# Ideally, the orange line lies on top of the blue line, i.e. the actual measured value is equal to the desired level in the scrubber. The green line can adjust in order to make sure the measured value matches the desired value.
#
# We then see that

# %% [markdown]
# ## 2. Navigating the asset hierarchy is useful when you don't know what you're looking at
#
# We can start by navigating up to the root of the asset hierarchy.

# %%
# select an asset id from the table above
first_row_asset_id = 3111454725058294
get_asset(first_row_asset_id).to_pandas()
# Out:
#                                                              0
# id                                            3111454725058294
# path         [6687602007296940, 4650652196144007, 311145472...
# name                                                        23
# parentId                                      4650652196144007
# description              GAS COMPRESSION AND RE-INJECTION (PH)
# metadata     {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...

# %%
# look at the parentId
parrent_id = 4650652196144007
get_asset(parent_id).to_pandas()
# Out:
#                                                              0
# id                                            4650652196144007
# path                      [6687602007296940, 4650652196144007]
# name                                                       VAL
# parentId                                      6687602007296940
# description                                  Valhall plattform
# metadata     {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...

# %%
# Cool, we found the Valhall plattform asset! Let's look at the parent of that
parent_id = 6687602007296940
get_asset(parent_id).to_pandas()
# Out:
#                               0
# id             6687602007296940
# path         [6687602007296940]
# name                    Aker BP
# description             Aker BP

# %% [markdown]
# We navigated all the way up to the AkerBP project! Note, we could also find that node by including description when getting the asset. For example:

# %%
get_assets(description="Aker BP").to_pandas()
# Out:
#   description                id     name                path
# 0     Aker BP  6687602007296940  Aker BP  [6687602007296940]

# %% [markdown]
# You can see that the get_assets() query gets the same asset as we found by navigating the asset tree. Now, when we are the top, we can also navigate downward the asset hiearchy.

# %%
# Explore the subtree below the root
akerbp_asset_id = 6687602007296940
akerbp_subtree = get_asset_subtree(akerbp_asset_id, depth=4)
akerbp_subtree.to_pandas()
# Out:
#                               description                id  \
# 0                                 Aker BP  6687602007296940
# 1                       Valhall plattform  4650652196144007
# 2   GAS COMPRESSION AND RE-INJECTION (PH)  3111454725058294
# 3  GAS COMPRESSION AND RE-INJECTION ON PH  6895991969886325
# 4      VRD - PH 1STSTGDISCCOOL COOLMED IN  1150715783816357
# 5             1ST STAGE COMPRESSION ON PH  4518112062673878
# 6             2ND STAGE COMPRESSION ON PH  5786472304680477
#
#                                             metadata  \
# 0                                                NaN
# 1  {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...
# 2  {'SOURCE_DB': 'workmate', 'SOURCE_TABLE': 'wma...
# 3  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 4  {'ELC_STATUS_ID': '1212', 'SOURCE_DB': 'workma...
# 5  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
# 6  {'ELC_STATUS_ID': '1211', 'SOURCE_DB': 'workma...
#
#                           name      parentId  \
# 0                      Aker BP           NaN
# 1                          VAL  6.687602e+15
# 2                           23  4.650652e+15
# 3                       230900  3.111455e+15
# 4                 23-TT-92604B  6.895992e+15
# 5  23-1ST STAGE COMPRESSION-PH  6.895992e+15
# 6  23-2ND STAGE COMPRESSION-PH  6.895992e+15
#
#                                                 path
# 0                                 [6687602007296940]
# 1               [6687602007296940, 4650652196144007]
# 2  [6687602007296940, 4650652196144007, 311145472...
# 3  [6687602007296940, 4650652196144007, 311145472...
# 4  [6687602007296940, 4650652196144007, 311145472...
# 5  [6687602007296940, 4650652196144007, 311145472...
# 6  [6687602007296940, 4650652196144007, 311145472...

# %% [markdown]
# Can you spot which assets have which parents in the table above?

# %% [markdown]
# ## Congrats, you've gotten started using the Cognite Data Platform! What's next?
#
# You can find ideas for what to model or explore on http://openindustrialdata.com/.
